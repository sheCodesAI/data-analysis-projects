# %% [markdown]
# <a href="https://colab.research.google.com/github/sheCodesAI/data-analysis-projects/blob/main/UdemyDataSet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv("/content/7. Udemy Courses.csv")

# %%
data.head()
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
# 2    75              482            1            47  Intermediate Level
# 3    75              850            3            43  Intermediate Level
# 4    75              940            3            32  Intermediate Level
#
#   content_duration   published_timestamp              subject
# ...

# %% [markdown]
# ## **1. wt all diff subs for which Udemy is offering courses**

# %%
data.subject.unique()
# Out:
# array(['Musical Instruments', 'Business Finance', 'Graphic Design',
#        'Web Development'], dtype=object)

# %% [markdown]
# ## **2. wt sub has max no. of courses?**

# %%
data.subject.value_counts().sort_values(ascending = False)
# Out:
# subject
# Web Development        1200
# Business Finance       1199
# Musical Instruments     680
# Graphic Design          603
# Name: count, dtype: int64

# %% [markdown]
# ## **3. show all courses which r free of cost**

# %%
data.head(1)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
#
#   price  num_subscribers  num_reviews  num_lectures       level  \
# 0    35             3137           18            68  All Levels
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments

# %%
data[data.is_paid == False].head(2)
# Out:
#     course_id                                       course_title  is_paid  \
# 41     286070        5 lecciones que todo guitarrista debe tomar    False
# 49     696630  7 Ways A Beginner Guitarist Can Sound Better, ...    False
#
#    price  num_subscribers  num_reviews  num_lectures           level  \
# 41  Free             4452          263            14  Beginner Level
# 49  Free             4529          193             7  Beginner Level
#
#    content_duration   published_timestamp              subject
# 41           1 hour  2014-08-23T05:08:14Z  Musical Instruments
# 49          36 mins  2015-12-21T18:50:50Z  Musical Instruments

# %% [markdown]
# ## **4. show all courses which are paid ?**

# %%
data[data.is_paid == True].head(2)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments
# 1           1 hour  2017-04-12T19:06:34Z  Musical Instruments

# %% [markdown]
# ## **5. which r top selling courses ?**

# %%
data.sort_values('num_subscribers' ,ascending = False).head(2)
# Out:
#       course_id                          course_title  is_paid price  \
# 2230      41295  Learn HTML5 Programming From Scratch    False  Free
# 776       59014        Coding for Entrepreneurs Basic    False  Free
#
#       num_subscribers  num_reviews  num_lectures           level  \
# 2230           268923         8629            45      All Levels
# 776            161029          279            27  Beginner Level
#
#      content_duration   published_timestamp          subject
# 2230       10.5 hours  2013-02-14T07:03:41Z  Web Development
# 776         3.5 hours  2013-06-09T15:51:55Z  Web Development

# %% [markdown]
# ## **6. which are least selling courses ?**

# %%
data[['course_title', 'num_subscribers']].sort_values( by = 'num_subscribers', ascending = True).head(2)
# Out:
#                                            course_title  num_subscribers
# 98    Accounting - The 6 most important rules you mu...                0
# 2350  Learn to create Text fire effect in Adobe Phot...                0

# %% [markdown]
# ## **7. show all the courses of Graphic design where price is below 100**

# %%
data[(data.subject == 'Graphic Design') & (data.price<='100')].head(2)
# Out:
#      course_id                                  course_title  is_paid price  \
# 47     1269190     7 Secrets To Designing In Black and White     True   100
# 169     983444  Adobe Illustrator Vectors For Hand Letterers     True   100
#
#      num_subscribers  num_reviews  num_lectures           level  \
# 47              1000            1            12      All Levels
# 169               23            2             9  Beginner Level
#
#     content_duration   published_timestamp         subject
# 47         1.5 hours  2017-06-27T19:55:18Z  Graphic Design
# 169          37 mins  2016-10-21T18:50:38Z  Graphic Design

# %% [markdown]
# ## **8 list out all courses that are related to python**

# %%
data.head(0)
# Out:
# Empty DataFrame
# Columns: [course_id, course_title, is_paid, price, num_subscribers, num_reviews, num_lectures, level, content_duration, published_timestamp, subject]
# Index: []

# %%
data[data.course_title.str.contains('Python')].head(3)
# Out:
#      course_id                                       course_title  is_paid  \
# 216     599504  Advanced Scalable Python Web Development Using...     True
# 777      47963  Coding for Entrepreneurs: Learn Python, Django...     True
# 814     631128  Complete Python Web Course: Build 8 Python Web...     True
#
#     price  num_subscribers  num_reviews  num_lectures               level  \
# 216   120             1299           56            71  Intermediate Level
# 777   195            23412          799           251          All Levels
# 814   110             7489          941           173          All Levels
#
#     content_duration   published_timestamp          subject
# 216         14 hours  2016-08-11T22:09:24Z  Web Development
# 777         45 hours  2013-04-08T00:46:14Z  Web Development
# 814         16 hours  2015-11-08T20:57:35Z  Web Development

# %% [markdown]
# ## **9 what are courses that published in year 2015**

# %%
data.dtypes
# Out:
# course_id               int64
# course_title           object
# is_paid                  bool
# price                  object
# num_subscribers         int64
# num_reviews             int64
# num_lectures            int64
# level                  object
# content_duration       object
# published_timestamp    object
# subject                object
# dtype: object

# %%
data['published_timestamp'] = pd.to_datetime(data.published_timestamp)

# %%
data.dtypes
# Out:
# course_id                            int64
# course_title                        object
# is_paid                               bool
# price                               object
# num_subscribers                      int64
# num_reviews                          int64
# num_lectures                         int64
# level                               object
# content_duration                    object
# published_timestamp    datetime64[ns, UTC]
# subject                             object
# dtype: object

# %%
data['year'] = data['published_timestamp'].dt.year

# %%
data.head(2)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
#
#   content_duration       published_timestamp              subject  year
# 0        1.5 hours 2014-09-18 05:07:05+00:00  Musical Instruments  2014
# 1           1 hour 2017-04-12 19:06:34+00:00  Musical Instruments  2017

# %%
data[data.year == 2015].head(2)
# Out:
#     course_id                                       course_title  is_paid  \
# 10     591880  1 - Concepts of Statistics For Beginners Step ...     True
# 16     302450        10 Numbers Every Business Owner Should Know     True
#
#    price  num_subscribers  num_reviews  num_lectures           level  \
# 10   200              273            4            15  Beginner Level
# 16    20               13            1             9      All Levels
#
#    content_duration       published_timestamp           subject  year
# 10          31 mins 2015-08-30 22:48:34+00:00  Business Finance  2015
# 16           1 hour 2015-03-08 19:11:24+00:00  Business Finance  2015

# %% [markdown]
# ## **10 what are the max number of subscribers for each level of courses?**

# %%
data.groupby('level')['num_subscribers'].count()
# Out:
# level
# All Levels            1932
# Beginner Level        1271
# Expert Level            58
# Intermediate Level     421
# Name: num_subscribers, dtype: int64

# %%
data.level.unique()
# Out:
# array(['All Levels', 'Intermediate Level', 'Beginner Level',
#        'Expert Level'], dtype=object)

# %%
data.groupby('level').max().head(2)
# Out:
#                 course_id                                course_title  \
# level
# All Levels        1277924               ６時間でインターバンク市場を攻略！最短距離でトレード基礎力
# Beginner Level    1282064  ７日でマスター  ビギナー向け Adobe Illustrator　どきどきセミナー
#
#                 is_paid price  num_subscribers  num_reviews  num_lectures  \
# level
# All Levels         True  Free           268923        27445           544
# Beginner Level     True  Free           161029         5924           779
#
#                content_duration       published_timestamp          subject  \
# level
# All Levels            9.5 hours 2017-07-06 21:16:13+00:00  Web Development
# Beginner Level        9.5 hours 2017-07-06 21:46:30+00:00  Web Development
#
#                 year
# level
# All Levels      2017
# Beginner Level  2017
