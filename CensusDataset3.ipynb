# %% [markdown]
# <a href="https://colab.research.google.com/github/sheCodesAI/data-analysis-projects/blob/main/CensusDataset3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv(r"/content/6. India Census 2011.csv")

# %%
data.head(2)
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 0    439654   229064        190899           38165  ...        1700   5600
# 1    335649   214866        162578           52288  ...        1489   5559
#
#    Buddhists  Jains  Secondary_Education  Higher_Education  \
# 0         66     39                74948             39709
# 1         47      6                66459             41367
#
#    Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# 0               21751          600759           178435         89679
# 1               27950          503223           160933         88978
#
# [2 rows x 25 columns]

# %% [markdown]
# ## **1. how will you hide the indexes of dataframe?**

# %%
data.head(2).style.hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_8d119" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_8d119_level0_col0" class="col_heading level0 col0" >District_code</th>
#       <th id="T_8d119_level0_col1" class="col_heading level0 col1" >State_name</th>
#       <th id="T_8d119_level0_col2" class="col_heading level0 col2" >District_name</th>
#       <th id="T_8d119_level0_col3" class="col_heading level0 col3" >Population</th>
#       <th id="T_8d119_level0_col4" class="col_heading level0 col4" >Male</th>
#       <th id="T_8d119_level0_col5" class="col_heading level0 col5" >Female</th>
#       <th id="T_8d119_level0_col6" class="col_heading level0 col6" >Literate</th>
#       <th id="T_8d119_level0_col7" class="col_heading level0 col7" >Workers</th>
#       <th id="T_8d119_level0_col8" class="col_heading level0 col8" >Male_Workers</th>
#       <th id="T_8d119_level0_col9" class="col_heading level0 col9" >Female_Workers</th>
# ...

# %% [markdown]
# ## **2. how can we set the caption or heading in df**

# %%
data.head(2).style.set_caption('india sensus 2011 dataset')
# Out:
# <style type="text/css">
# </style>
# <table id="T_7a0c5" class="dataframe">
#   <caption>india sensus 2011 dataset</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7a0c5_level0_col0" class="col_heading level0 col0" >District_code</th>
#       <th id="T_7a0c5_level0_col1" class="col_heading level0 col1" >State_name</th>
#       <th id="T_7a0c5_level0_col2" class="col_heading level0 col2" >District_name</th>
#       <th id="T_7a0c5_level0_col3" class="col_heading level0 col3" >Population</th>
#       <th id="T_7a0c5_level0_col4" class="col_heading level0 col4" >Male</th>
#       <th id="T_7a0c5_level0_col5" class="col_heading level0 col5" >Female</th>
#       <th id="T_7a0c5_level0_col6" class="col_heading level0 col6" >Literate</th>
#       <th id="T_7a0c5_level0_col7" class="col_heading level0 col7" >Workers</th>
#       <th id="T_7a0c5_level0_col8" class="col_heading level0 col8" >Male_Workers</th>
# ...

# %%
data.head(2).style.set_caption('india sensus 2011 dataset')
# Out:
# <style type="text/css">
# </style>
# <table id="T_cd167" class="dataframe">
#   <caption>india sensus 2011 dataset</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cd167_level0_col0" class="col_heading level0 col0" >District_code</th>
#       <th id="T_cd167_level0_col1" class="col_heading level0 col1" >State_name</th>
#       <th id="T_cd167_level0_col2" class="col_heading level0 col2" >District_name</th>
#       <th id="T_cd167_level0_col3" class="col_heading level0 col3" >Population</th>
#       <th id="T_cd167_level0_col4" class="col_heading level0 col4" >Male</th>
#       <th id="T_cd167_level0_col5" class="col_heading level0 col5" >Female</th>
#       <th id="T_cd167_level0_col6" class="col_heading level0 col6" >Literate</th>
#       <th id="T_cd167_level0_col7" class="col_heading level0 col7" >Workers</th>
#       <th id="T_cd167_level0_col8" class="col_heading level0 col8" >Male_Workers</th>
# ...

# %% [markdown]
# ## **3. show records related with districts : New Delhi, Jaipur, Lucknow**

# %%
data[data['District_name'].isin(['Jaipur', 'Lucknow', 'New Delhi'])]
# Out:
#      District_code     State_name District_name  Population     Male   Female  \
# 93              94   NCT OF DELHI     New Delhi      142004    77942    64062
# 109            110      RAJASTHAN        Jaipur     6626178  3468507  3157671
# 156            157  UTTAR PRADESH       Lucknow     4589838  2394476  2195362
#
#      Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 93     114179    59541         46940           12601  ...        4852   2933
# 109   4300965  2464893       1714947          749946  ...       12708  18782
# 156   3127260  1542806       1226399          316407  ...       20493  23883
#
#      Buddhists  Jains  Secondary_Education  Higher_Education  \
# 93         312    679                15942             17742
# 109       1020  81079               659389            455527
# 156       3877   4975               428121            378742
#
#      Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# ...

# %% [markdown]
# ## **4. Calculate state wise:**
# ### **a. Total no. of population**
# ### **b. total no. of population with different regions**

# %%
data.head(2)
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 0    439654   229064        190899           38165  ...        1700   5600
# 1    335649   214866        162578           52288  ...        1489   5559
#
#    Buddhists  Jains  Secondary_Education  Higher_Education  \
# 0         66     39                74948             39709
# 1         47      6                66459             41367
#
#    Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# 0               21751          600759           178435         89679
# 1               27950          503223           160933         88978
#
# [2 rows x 25 columns]

# %%
data.groupby('State_name').Population.sum().sort_values().head()
# Out:
# State_name
# LAKSHADWEEP                     64473
# DAMAN AND DIU                  243247
# DADRA AND NAGAR HAVELI         343709
# ANDAMAN AND NICOBAR ISLANDS    380581
# SIKKIM                         610577
# Name: Population, dtype: int64

# %%
data.columns
# Out:
# Index(['District_code', 'State_name', 'District_name', 'Population', 'Male',
#        'Female', 'Literate', 'Workers', 'Male_Workers', 'Female_Workers',
#        'Cultivator_Workers', 'Agricultural_Workers', 'Household_Workers',
#        'Hindus', 'Muslims', 'Christians', 'Sikhs', 'Buddhists', 'Jains',
#        'Secondary_Education', 'Higher_Education', 'Graduate_Education',
#        'Age_Group_0_29', 'Age_Group_30_49', 'Age_Group_50'],
#       dtype='object')

# %%
data.groupby('State_name')[['Hindus', 'Muslims', 'Christians', 'Sikhs', 'Buddhists', 'Jains']].sum().sort_values(by = ['Hindus', 'Muslims', 'Christians', 'Sikhs', 'Buddhists', 'Jains']).head(2)
# Out:
#              Hindus  Muslims  Christians  Sikhs  Buddhists  Jains
# State_name
# LAKSHADWEEP    1788    62268         317      8         10     11
# MIZORAM       30136    14832      956331    286      93411    376

# %% [markdown]
# ## **5. how many male workers in Maharashtra?**

# %%
data.head(1)
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 0    439654   229064        190899           38165  ...        1700   5600
#
#    Buddhists  Jains  Secondary_Education  Higher_Education  \
# 0         66     39                74948             39709
#
#    Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# 0               21751          600759           178435         89679
#
# [1 rows x 25 columns]

# %%
data[data.State_name == 'MAHARASHTRA']['Male_Workers'].sum()
# Out:
# np.int64(32616875)

# %% [markdown]
# ## **6. How to set a column as index of the DF**

# %%
data = pd.read_csv(r"/content/6. India Census 2011.csv")

# %%
data.set_index('District_code', inplace = True)

# %%
data.head(3)
# Out:
#                       State_name District_name  Population    Male  Female  \
# District_code
# 1              JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 2              JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 3              JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
#
#                Literate  Workers  Male_Workers  Female_Workers  \
# District_code
# 1                439654   229064        190899           38165
# 2                335649   214866        162578           52288
# 3                 93770    75079         53265           21814
#
#                Cultivator_Workers  ...  Christians  Sikhs  Buddhists  Jains  \
# District_code                      ...
# 1                           34680  ...        1700   5600         66     39
# 2                           55299  ...        1489   5559         47      6
# 3                           20869  ...         658   1092      88635    103
#
# ...

# %% [markdown]
# ## **7.a  Add a suffix to the col names**

# %%
data.head(1)
# Out:
#                       State_name District_name  Population    Male  Female  \
# District_code
# 1              JAMMU AND KASHMIR       Kupwara      870354  474190  396164
#
#                Literate  Workers  Male_Workers  Female_Workers  \
# District_code
# 1                439654   229064        190899           38165
#
#                Cultivator_Workers  ...  Christians  Sikhs  Buddhists  Jains  \
# District_code                      ...
# 1                           34680  ...        1700   5600         66     39
#
#                Secondary_Education  Higher_Education  Graduate_Education  \
# District_code
# 1                            74948             39709               21751
#
#                Age_Group_0_29  Age_Group_30_49  Age_Group_50
# District_code
# 1                      600759           178435         89679
#
# [1 rows x 24 columns]

# %%
data.add_suffix('_').head(1)
# Out:
#                      State_name_ District_name_  Population_   Male_  Female_  \
# District_code
# 1              JAMMU AND KASHMIR        Kupwara       870354  474190   396164
#
#                Literate_  Workers_  Male_Workers_  Female_Workers_  \
# District_code
# 1                 439654    229064         190899            38165
#
#                Cultivator_Workers_  ...  Christians_  Sikhs_  Buddhists_  \
# District_code                       ...
# 1                            34680  ...         1700    5600          66
#
#                Jains_  Secondary_Education_  Higher_Education_  \
# District_code
# 1                  39                 74948              39709
#
#                Graduate_Education_  Age_Group_0_29_  Age_Group_30_49_  \
# District_code
# 1                            21751           600759            178435
#
#                Age_Group_50_
# District_code
# 1                      89679
#
# [1 rows x 24 columns]

# %%
data = data.add_prefix('_').head(1)
# make changes permenantly : assign to data again
# Out:
#                      _State_name _District_name  _Population   _Male  _Female  \
# District_code
# 1              JAMMU AND KASHMIR        Kupwara       870354  474190   396164
#
#                _Literate  _Workers  _Male_Workers  _Female_Workers  \
# District_code
# 1                 439654    229064         190899            38165
#
#                _Cultivator_Workers  ...  _Christians  _Sikhs  _Buddhists  \
# District_code                       ...
# 1                            34680  ...         1700    5600          66
#
#                _Jains  _Secondary_Education  _Higher_Education  \
# District_code
# 1                  39                 74948              39709
#
#                _Graduate_Education  _Age_Group_0_29  _Age_Group_30_49  \
# District_code
# 1                            21751           600759            178435
#
#                _Age_Group_50
# District_code
# 1                      89679
#
# [1 rows x 24 columns]
