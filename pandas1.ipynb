# %% [markdown]
# <a href="https://colab.research.google.com/github/niraja03/data-analysis-practice/blob/main/pandas1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = [1,2,3,4,5]
index = ['a','b','c','d','e']
series = pd.Series(data, index=index)
print(series)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
## create data frames
df = pd.DataFrame([[1,2,3], [4,5,6], [7,8,9]])
print(df)
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9
